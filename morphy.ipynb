# %% [markdown]
# # CmpE 561 Natural Language Processing - Application Project 1 (Fall 17)
# ### Arda Akdemir & Burak Suyunu
# ### Instructor: Tunga Güngör

# %% [markdown]
# ## Introduction
#
# In this project, we implemented a morphological analyzer for English using the two-level morphology paradigm. The components of the analyzer will have the following properties:
#
# * **Lexicon**: The lexicon includes 100 stems. There are stems with varying lengths; there are several stems of different POSs (nouns, verbs, adjectives, prepositions, etc.); there are also ambiguous stems (e.g. a stem which can be both noun and verb)
#
# * **Morphotactics**: The morphotactics includes all the suffixes used for nouns, verbs, adjectives, and adverbs. Prefixes are out of the scope of the project; only suffixes are considered. It is clear that more than one suffix may be attached to a stem (e.g. compute + - er + -ize + -ation → computerization), and the order of the suffixes are important (e.g. *compute + -ize + -ation + -er). The lexicon includes entries to which these suffixes can be applied..
#
# * **Morphophonemics**: We used e-insertion, e-deletion, y-replacement rules in this project.

# %% [markdown]
# ## Lexicon
#
# We have 2 different documents as our dataset.
#
# * **Words.txt**: This document includes stems, POS tag of the stems, and possible initial suffixes that these stems can get. We also included the new form of the stems after getting the suffixes. The format of the document is as follows:
# "stem1" "POS tag of the stem2"
# "stem1+suffix11" "suffix11" "POS tag of the stem1+suffix11"
# ...
# "stem1+suffix1N" "suffix1N" "POS tag of the stem1+suffix1N"
# .
# "stem2" "POS tag of the stem2"
# "stem2+suffix21" "suffix21" "POS tag of the stem2+suffix21"
# ...
# "stem2+suffix2M" "suffix2M" "POS tag of the stem2+suffix2M"
# .
# **Example Input:**
# compute v
# compute er n
# computation ation n
# computerize ize v
# computable able adj
# .
# invest v
# investor or n
# investment ment n
# investing ing n
#
#
# * **Suffixes.txt**: This document includes suffix interactions which means that which suffixes can a word take that ends with a specific suffix. In each line there are 4 strings:
# "suffix1" "suffix2" "POS tag before suffix2 added" "POS tag after suffix2 added"
# For example; "_al ist n n_" means that a noun word ending with _al_ suffix can take _ist_ suffix and POS tag of the word changes to noun. Nation_al_ + _ist_ => Nation_alist_
# .
# **Example Input:**
# ful ness adj n
# less ness adj n
# less ly adj adv
# al ist n n
# al ize n v

# %% [markdown]
# ## Data Structures
#
# We used dictionaries to store our data. We have 5 main variables (dictionaries). (Derived word means stem+affixes)
# * **stems**: key: stem word => value: POS tag and list of possible initial suffixes with POS tag of words after adding this suffixes.
# _'build': ['v', [['ing', 'n'], ['er', 'n'], ['s', 'v']]]_ : build is the stem. build is a verb. build can take ing, er, s suffixes and these suffixes convert POS tag of the word build from verb to noun, noun and verb respectively.
#
#
# * **firstDerivedWords**: key: derived word => value: [[stem, POS tag], [suffix, POS tag before suffix is added, POS tag after suffix is added]]
# _'musical': [['music', 'n'], ['al', 'n', 'adj']]_ : musical is the derived word. music is the stem of the word and it is a noun. al is the suffix music got, and al suffix turns the POS tag of music from noun to adjective.
#
#
# * **suffixes**: key: suffix => value: [K*[newSuffix, POS tag before newSuffix added, POS tag after newSuffix added]] (K is the number of new suffixes that can be added after the key suffix)
# _'ive': [['ity', 'adj', 'n'], ['ness', 'adj', 'n'], ['ly', 'adj', 'adv']]_ : ive is the suffix. When a word ends with suffix ive which makes the word adjective, can also take ity, ness and ly suffixes and this suffixses change the POS tag of the word from adjective to noun, noun and adverb respectively.
# _create + ive + ity = creativity_
#
#
# * **secondDerivedWords**: key: derived word => value: [[stem, POS tag], K*[suffix, POS tag before suffix is added, POS tag after suffix is added]] (K is the number of suffixes that derived word has)
# _'receivers': [['receive', 'v'], ['er', 'v', 'n'], ['s', 'n', 'n']]_ : receivers is the derived word. receive is the stem of the word and it is a verb. er is the first suffix receive got, and er suffix turns the POS tag of receive from verb to noun (receiver). s is the second suffix receive got (or the suffix that reciever got), and s suffix turns the POS tag of receiver from noun to noun (receivers).
#
#
# * **derivedWords**: This is the union of _firstDerivedWords_ and _secondDerivedWords_ dictionaries. We use _derivedWords_ dictionary and _stems_ dictionary to convert words from surface form to lexical form and vice versa. **So derivedWords dictionary is actually our finite state transducer.**

# %% [markdown]
# ## Methodology
#
# We create our FSTs in two steps:
#
# 1. First, we made a list of stems with their initial suffixes. The word initial is important, because we were not intrested in two or three consecutive suffixes. Only the first suffixes.
# 2. Second, we made the Suffixes list which includes the order of suffixes. So, this list actually represents morphotactics. We used this list to generate new derived words by adding appropriate suffixes to the old derived words according to mophotactics.
#
#
# * In the first part, we directly created words with one suffixes from stems by hand (firstDerivedWords). Because it is nearly impossible to make an automatical system for 100 words that knows which stem can take which suffix.
# * In the second step, we used morphotactics to generate new words on top of the firstDerivedWords, because here we only used suffix-suffix interactions. This word generation process might generate words that are not used in English, but actually they should be gramatically correct.
# * We used our ortographic rules while combining suffixes, as mentioned in 2. But, in the first part we didn't use ortograpchic rules. We directly pulled the derived words from the stems lexicon because we wanted the root of the word to be in the correct form. (We could also do it with ortographic rules but because we didn't cover all the rules there were be lots of misspelled words from root).
# * As a last note, even if our FST doesn't seem like a real node structured FST, actually it is created in a very similar way. It starts from the stem and builds up to a new word by using morphotactics and morphophonemics. It stores enough information to show the formation process and to convert structure into both directions (surface => lexicon, lexicon => surface). Also, for fast access we used dictionaries.

# %% [markdown]
# ## Algorithm
#
# 1. Read Stems.txt. Create stems and firstDerivedWords dictionaries. Creation of these two dictionaries are very straight forward, because Stems.txt has all the info that is needed.
# 2. Read Suffixes.txt. Using morphotactics defined in Suffixes.txt create new words on top of firstDerivedWords and store in secondDerivedWords. Use Morphophonemics while combining suffixes.
# 3. Combine firstDerivedWords and secondDerivedWords dictionaries into derivedWords dictionaries. derivedWords with stems function as our completed FSTs.
# 4. For a given surface form word, program can transform it into lexical form (vice versa)

# %%
stems = dict()
firstDerivedWords = dict()

file = open("words.txt", "r")
word = ''
for line in file.readlines():
    if len(line.split()) == 1:
        continue
    if len(line.split()) == 2:
        word = line.split()[0]
        pos = line.split()[1]
        stems[word] = [pos, []]
    else:
        derWord = line.split()[0]
        suf = line.split()[1]
        derPos = line.split()[2]
        
        stems[word][1].append([suf, derPos])
        firstDerivedWords[derWord] = [[word, pos], [suf, pos, derPos]]

# %%
stems
# Out:
# {'across': ['prp', []],
#  'after': ['prp', []],
#  'appear': ['v', [['ance', 'n'], ['s', 'v'], ['ing', 'v']]],
#  'area': ['n', [['s', 'n'], ['al', 'adj']]],
#  'army': ['n', [['s', 'n']]],
#  'art': ['n', [['ist', 'n'], ['s', 'n']]],
#  'article': ['n', [['s', 'n'], ['ed', 'adj']]],
#  'become': ['v', [['s', 'v']]],
#  'begin': ['v', [['ing', 'n'], ['n', 'n'], ['s', 'v']]],
#  'believe': ['v', [['s', 'v'], ['ed', 'v'], ['er', 'n']]],
#  'big': ['adj', [['er', 'adj'], ['est', 'adj'], ['ness', 'n']]],
#  'bird': ['n', [['s', 'n']]],
#  'build': ['v', [['ing', 'n'], ['er', 'n'], ['s', 'v']]],
#  'by': ['prp', []],
#  'calculate': ['v',
#   [['er', 'n'], ['ation', 'n'], ['able', 'adj'], ['ed', 'v']]],
#  'camera': ['n', [['s', 'n']]],
#  'clear': ['adj',
#   [['ly', 'adv'], ['er', 'adj'], ['est', 'adj'], ['ness', 'n']]],
#  'compute': ['v',
#   [['er', 'n'], ['ation', 'n'], ['ize', 'v'], ['able', 'adj']]],
#  'consider': ['v', [['ing', 'v'], ['ation', 'n'], ['ate', 'adj'], ['s', 'v']]],
#  'consume': ['v', [['er', 'n'], ['ing', 'n'], ['ed', 'v'], ['s', 'v']]],
#  'control': ['n', [['s', 'n'], ['able', 'adj'], ['er', 'n'], ['ed', 'n']]],
#  'data': ['n', []],
#  'die': ['v', [['s', 'v'], ['ed', 'v']]],
#  'difficult': ['adj', [['y', 'n'], ['ly', 'adv']]],
#  'disk': ['n', [['s', 'n']]],
#  'easy': ['adj', [['er', 'adj'], ['est', 'adj'], ['ly', 'adv']]],
#  'event': ['n', [['s', 'n'], ['ful', 'adj'], ['ual', 'adj']]],
#  'exam': ['n', [['s', 'n'], ['ine', 'v']]],
#  'fact': ['n', [['s', 'n'], ['ual', 'adj'], ['ive', 'adj'], ['ion', 'n']]],
#  'family': ['n', [['s', 'n']]],
#  'fast': ['adj', [['er', 'adj'], ['est', 'adj'], ['en', 'v']]],
#  'feel': ['v', [['ing', 'n'], ['er', 'n']]],
#  'food': ['n', [['s', 'n']]],
#  'get': ['v', [['ing', 'v'], ['s', 'v']]],
#  'grow': ['v', [['s', 'v'], ['ing', 'v'], ['th', 'n']]],
#  'hard': ['adj',
#   [['er', 'adj'],
#    ['est', 'adj'],
#    ['ness', 'n'],
#    ['ly', 'adv'],
#    ['en', 'v'],
#    ['ship', 'n']]],
#  'hear': ['v', [['s', 'v'], ['ing', 'n'], ['er', 'n']]],
#  'help': ['n', [['s', 'n'], ['er', 'n'], ['ful', 'adj'], ['less', 'adj']]],
#  'high': ['adj',
#   [['er', 'adj'], ['ly', 'adv'], ['est', 'adj'], ['ness', 'n']]],
#  'history': ['n', [['ical', 'adj'], ['s', 'n']]],
#  'huge': ['adj', [['ly', 'adv'], ['ness', 'n']]],
#  'idea': ['n', [['s', 'n'], ['al', 'n']]],
#  'in': ['prp', []],
#  'invest': ['v', [['or', 'n'], ['ment', 'n'], ['ing', 'n']]],
#  'law': ['n', [['s', 'n'], ['yer', 'n'], ['ful', 'adj'], ['less', 'adj']]],
#  'library': ['n', [['s', 'n']]],
#  'live': ['v', [['ed', 'v'], ['s', 'v'], ['ly', 'adj']]],
#  'long': ['adj',
#   [['er', 'adj'], ['est', 'adj'], ['ish', 'adj'], ['evity', 'n']]],
#  'look': ['v', [['ing', 'n'], ['ed', 'v'], ['s', 'v']]],
#  'lose': ['v', [['ing', 'v'], ['er', 'n'], ['s', 'v']]],
#  'low': ['adj', [['er', 'adj'], ['est', 'adj'], ['ly', 'adv'], ['ness', 'n']]],
#  'make': ['v', [['r', 'n'], ['s', 'v']]],
#  'map': ['n', [['s', 'n'], ['er', 'n']]],
#  'math': ['n', [['s', 'n']]],
#  'mean': ['v', [['ing', 'n']]],
#  'meat': ['n', [['s', 'n'], ['y', 'adj'], ['er', 'adj'], ['est', 'adj']]],
#  'media': ['n', [['s', 'n'], ['tive', 'adj']]],
#  'method': ['n', [['s', 'n'], ['logy', 'n'], ['ize', 'v'], ['ical', 'adj']]],
#  'moment': ['n', [['s', 'n'], ['ary', 'adj'], ['um', 'n']]],
#  'music': ['n', [['s', 'n'], ['al', 'adj'], ['ian', 'n']]],
#  'nation': ['n', [['s', 'n'], ['al', 'n']]],
#  'night': ['n', [['s', 'n'], ['ly', 'adj']]],
#  'of': ['prp', []],
#  'office': ['n', [['s', 'n'], ['er', 'n']]],
#  'on': ['prp', []],
#  'problem': ['n', [['s', 'n'], ['atic', 'adj']]],
#  'produce': ['v', [['tion', 'n'], ['ive', 'adj'], ['er', 'n'], ['t', 'adj']]],
#  'race': ['n', [['s', 'n'], ['er', 'n']]],
#  'reach': ['v', [['s', 'v'], ['ing', 'n'], ['er', 'n']]],
#  'receive': ['v', [['s', 'v'], ['ing', 'n'], ['ed', 'v'], ['er', 'n']]],
#  'say': ['v', [['ing', 'n'], ['s', 'v']]],
#  'science': ['n', [['s', 'n']]],
#  'see': ['v', [['ing', 'n'], ['s', 'v']]],
#  'serve': ['v', [['ed', 'v'], ['s', 'v'], ['er', 'n']]],
#  'set': ['v', [['ing', 'n'], ['s', 'v']]],
#  'short': ['adj',
#   [['er', 'adj'], ['est', 'adj'], ['ly', 'adv'], ['age', 'n'], ['en', 'v']]],
#  'show': ['v', [['y', 'adj'], ['s', 'v'], ['ed', 'v']]],
#  'simple': ['adj',
#   [['er', 'adj'], ['est', 'adj'], ['city', 'n'], ['ness', 'n']]],
#  'slow': ['adj', [['ly', 'adv'], ['er', 'adj'], ['est', 'adj']]],
#  'small': ['adj',
#   [['er', 'adj'], ['est', 'adj'], ['ness', 'n'], ['ish', 'adj']]],
#  'smart': ['adj',
#   [['er', 'adj'], ['est', 'adj'], ['ly', 'adv'], ['ness', 'n']]],
#  'soft': ['adj',
#   [['er', 'adj'], ['est', 'adj'], ['ly', 'adv'], ['ness', 'n'], ['en', 'v']]],
#  'soup': ['n', [['s', 'n']]],
#  'story': ['n', [['s', 'n'], ['ing', 'n']]],
#  'strong': ['adj', [['er', 'adj'], ['est', 'adj'], ['ly', 'adv']]],
#  'system': ['n', [['s', 'n'], ['atic', 'adj'], ['ize', 'v']]],
#  'tall': ['adj', [['er', 'adj'], ['est', 'adj'], ['ness', 'n']]],
#  'teach': ['v', [['s', 'v'], ['er', 'n'], ['ing', 'n']]],
#  'theory': ['n', [['s', 'n'], ['atical', 'adj']]],
#  'thing': ['n', [['s', 'n']]],
#  'think': ['v', [['ing', 'v'], ['s', 'v'], ['able', 'adj']]],
#  'tough': ['adj',
#   [['er', 'adj'], ['est', 'adj'], ['ly', 'adv'], ['ness', 'n'], ['en', 'v']]],
#  'up': ['prp', []],
#  'video': ['n', [['s', 'n'], ['ing', 'v']]],
#  'weak': ['adj',
#   [['er', 'adj'], ['est', 'adj'], ['ly', 'adv'], ['en', 'v'], ['ness', 'n']]],
#  'with': ['prp', []],
#  'wood': ['n', [['s', 'n'], ['y', 'adj']]],
#  'world': ['n', [['s', 'n'], ['wide', 'adj']]],
#  'year': ['n', [['s', 'n'], ['ly', 'adv']]]}

# %%
firstDerivedWords
# Out:
# {'appearance': [['appear', 'v'], ['ance', 'v', 'n']],
#  'appearing': [['appear', 'v'], ['ing', 'v', 'v']],
#  'appears': [['appear', 'v'], ['s', 'v', 'v']],
#  'areal': [['area', 'n'], ['al', 'n', 'adj']],
#  'areas': [['area', 'n'], ['s', 'n', 'n']],
#  'armies': [['army', 'n'], ['s', 'n', 'n']],
#  'articled': [['article', 'n'], ['ed', 'n', 'adj']],
#  'articles': [['article', 'n'], ['s', 'n', 'n']],
#  'artist': [['art', 'n'], ['ist', 'n', 'n']],
#  'arts': [['art', 'n'], ['s', 'n', 'n']],
#  'becomes': [['become', 'v'], ['s', 'v', 'v']],
#  'beginner': [['begin', 'v'], ['n', 'v', 'n']],
#  'beginning': [['begin', 'v'], ['ing', 'v', 'n']],
#  'begins': [['begin', 'v'], ['s', 'v', 'v']],
#  'believed': [['believe', 'v'], ['ed', 'v', 'v']],
#  'believer': [['believe', 'v'], ['er', 'v', 'n']],
#  'believes': [['believe', 'v'], ['s', 'v', 'v']],
#  'bigger': [['big', 'adj'], ['er', 'adj', 'adj']],
#  'biggest': [['big', 'adj'], ['est', 'adj', 'adj']],
#  'bigness': [['big', 'adj'], ['ness', 'adj', 'n']],
#  'birds': [['bird', 'n'], ['s', 'n', 'n']],
#  'builder': [['build', 'v'], ['er', 'v', 'n']],
#  'building': [['build', 'v'], ['ing', 'v', 'n']],
#  'builds': [['build', 'v'], ['s', 'v', 'v']],
#  'calculatable': [['calculate', 'v'], ['able', 'v', 'adj']],
#  'calculated': [['calculate', 'v'], ['ed', 'v', 'v']],
#  'calculater': [['calculate', 'v'], ['er', 'v', 'n']],
#  'calculation': [['calculate', 'v'], ['ation', 'v', 'n']],
#  'cameras': [['camera', 'n'], ['s', 'n', 'n']],
#  'clearer': [['clear', 'adj'], ['er', 'adj', 'adj']],
#  'clearest': [['clear', 'adj'], ['est', 'adj', 'adj']],
#  'clearly': [['clear', 'adj'], ['ly', 'adj', 'adv']],
#  'clearness': [['clear', 'adj'], ['ness', 'adj', 'n']],
#  'computable': [['compute', 'v'], ['able', 'v', 'adj']],
#  'computation': [['compute', 'v'], ['ation', 'v', 'n']],
#  'computer': [['compute', 'v'], ['er', 'v', 'n']],
#  'computize': [['compute', 'v'], ['ize', 'v', 'v']],
#  'considerate': [['consider', 'v'], ['ate', 'v', 'adj']],
#  'consideration': [['consider', 'v'], ['ation', 'v', 'n']],
#  'considering': [['consider', 'v'], ['ing', 'v', 'v']],
#  'considers': [['consider', 'v'], ['s', 'v', 'v']],
#  'consumed': [['consume', 'v'], ['ed', 'v', 'v']],
#  'consumer': [['consume', 'v'], ['er', 'v', 'n']],
#  'consumes': [['consume', 'v'], ['s', 'v', 'v']],
#  'consuming': [['consume', 'v'], ['ing', 'v', 'n']],
#  'controled': [['control', 'n'], ['ed', 'n', 'n']],
#  'controllable': [['control', 'n'], ['able', 'n', 'adj']],
#  'controlled': [['control', 'v'], ['ed', 'v', 'v']],
#  'controller': [['control', 'n'], ['er', 'n', 'n']],
#  'controlling': [['control', 'v'], ['ing', 'v', 'v']],
#  'controls': [['control', 'n'], ['s', 'n', 'n']],
#  'died': [['die', 'v'], ['ed', 'v', 'v']],
#  'dies': [['die', 'v'], ['s', 'v', 'v']],
#  'difficultly': [['difficult', 'adj'], ['ly', 'adj', 'adv']],
#  'difficulty': [['difficult', 'adj'], ['y', 'adj', 'n']],
#  'disks': [['disk', 'n'], ['s', 'n', 'n']],
#  'easier': [['easy', 'adj'], ['er', 'adj', 'adj']],
#  'easiest': [['easy', 'adj'], ['est', 'adj', 'adj']],
#  'easily': [['easy', 'adj'], ['ly', 'adj', 'adv']],
#  'eventful': [['event', 'n'], ['ful', 'n', 'adj']],
#  'events': [['event', 'n'], ['s', 'n', 'n']],
#  'eventual': [['event', 'n'], ['ual', 'n', 'adj']],
#  'examine': [['exam', 'n'], ['ine', 'n', 'v']],
#  'exams': [['exam', 'n'], ['s', 'n', 'n']],
#  'faction': [['fact', 'n'], ['ion', 'n', 'n']],
#  'factive': [['fact', 'n'], ['ive', 'n', 'adj']],
#  'facts': [['fact', 'n'], ['s', 'n', 'n']],
#  'factual': [['fact', 'n'], ['ual', 'n', 'adj']],
#  'families': [['family', 'n'], ['s', 'n', 'n']],
#  'fasten': [['fast', 'adj'], ['en', 'adj', 'v']],
#  'faster': [['fast', 'adj'], ['er', 'adj', 'adj']],
#  'fastest': [['fast', 'adj'], ['est', 'adj', 'adj']],
#  'feeler': [['feel', 'v'], ['er', 'v', 'n']],
#  'feeling': [['feel', 'v'], ['ing', 'v', 'n']],
#  'foods': [['food', 'n'], ['s', 'n', 'n']],
#  'gets': [['get', 'v'], ['s', 'v', 'v']],
#  'getting': [['get', 'v'], ['ing', 'v', 'v']],
#  'growing': [['grow', 'v'], ['ing', 'v', 'v']],
#  'grows': [['grow', 'v'], ['s', 'v', 'v']],
#  'growth': [['grow', 'v'], ['th', 'v', 'n']],
#  'harden': [['hard', 'adj'], ['en', 'adj', 'v']],
#  'harder': [['hard', 'adj'], ['er', 'adj', 'adj']],
#  'hardest': [['hard', 'adj'], ['est', 'adj', 'adj']],
#  'hardly': [['hard', 'adj'], ['ly', 'adj', 'adv']],
#  'hardness': [['hard', 'adj'], ['ness', 'adj', 'n']],
#  'hardship': [['hard', 'adj'], ['ship', 'adj', 'n']],
#  'hearer': [['hear', 'v'], ['er', 'v', 'n']],
#  'hearing': [['hear', 'v'], ['ing', 'v', 'n']],
#  'hears': [['hear', 'v'], ['s', 'v', 'v']],
#  'helped': [['help', 'v'], ['ed', 'v', 'v']],
#  'helper': [['help', 'n'], ['er', 'n', 'n']],
#  'helpful': [['help', 'n'], ['ful', 'n', 'adj']],
#  'helpless': [['help', 'n'], ['less', 'n', 'adj']],
#  'helps': [['help', 'n'], ['s', 'n', 'n']],
#  'higher': [['high', 'adj'], ['er', 'adj', 'adj']],
#  'highest': [['high', 'adj'], ['est', 'adj', 'adj']],
#  'highly': [['high', 'adj'], ['ly', 'adj', 'adv']],
#  'highness': [['high', 'adj'], ['ness', 'adj', 'n']],
#  'historical': [['history', 'n'], ['ical', 'n', 'adj']],
#  'histories': [['history', 'n'], ['s', 'n', 'n']],
#  'hugely': [['huge', 'adj'], ['ly', 'adj', 'adv']],
#  'hugeness': [['huge', 'adj'], ['ness', 'adj', 'n']],
#  'ideal': [['idea', 'n'], ['al', 'n', 'n']],
#  'ideas': [['idea', 'n'], ['s', 'n', 'n']],
#  'investing': [['invest', 'v'], ['ing', 'v', 'n']],
#  'investment': [['invest', 'v'], ['ment', 'v', 'n']],
#  'investor': [['invest', 'v'], ['or', 'v', 'n']],
#  'lawful': [['law', 'n'], ['ful', 'n', 'adj']],
#  'lawless': [['law', 'n'], ['less', 'n', 'adj']],
#  'laws': [['law', 'n'], ['s', 'n', 'n']],
#  'lawyer': [['law', 'n'], ['yer', 'n', 'n']],
#  'libraries': [['library', 'n'], ['s', 'n', 'n']],
#  'lived': [['live', 'v'], ['ed', 'v', 'v']],
#  'lively': [['live', 'v'], ['ly', 'v', 'adj']],
#  'lives': [['live', 'v'], ['s', 'v', 'v']],
#  'longer': [['long', 'adj'], ['er', 'adj', 'adj']],
#  'longest': [['long', 'adj'], ['est', 'adj', 'adj']],
#  'longevity': [['long', 'adj'], ['evity', 'adj', 'n']],
#  'longish': [['long', 'adj'], ['ish', 'adj', 'adj']],
#  'looked': [['look', 'v'], ['ed', 'v', 'v']],
#  'looking': [['look', 'v'], ['ing', 'v', 'n']],
#  'looks': [['look', 'v'], ['s', 'v', 'v']],
#  'loser': [['lose', 'v'], ['er', 'v', 'n']],
#  'loses': [['lose', 'v'], ['s', 'v', 'v']],
#  'losing': [['lose', 'v'], ['ing', 'v', 'v']],
#  'lower': [['low', 'adj'], ['er', 'adj', 'adj']],
#  'lowest': [['low', 'adj'], ['est', 'adj', 'adj']],
#  'lowly': [['low', 'adj'], ['ly', 'adj', 'adv']],
#  'lowness': [['low', 'adj'], ['ness', 'adj', 'n']],
#  'maker': [['make', 'v'], ['r', 'v', 'n']],
#  'makes': [['make', 'v'], ['s', 'v', 'v']],
#  'mapped': [['map', 'v'], ['ed', 'v', 'v']],
#  'mapper': [['map', 'n'], ['er', 'n', 'n']],
#  'mapping': [['map', 'v'], ['ing', 'v', 'n']],
#  'maps': [['map', 'n'], ['s', 'n', 'n']],
#  'maths': [['math', 'n'], ['s', 'n', 'n']],
#  'meadias': [['media', 'n'], ['s', 'n', 'n']],
#  'meaning': [['mean', 'v'], ['ing', 'v', 'n']],
#  'meatier': [['meat', 'n'], ['er', 'n', 'adj']],
#  'meatiest': [['meat', 'n'], ['est', 'n', 'adj']],
#  'meats': [['meat', 'n'], ['s', 'n', 'n']],
#  'meaty': [['meat', 'n'], ['y', 'n', 'adj']],
#  'mediative': [['media', 'n'], ['tive', 'n', 'adj']],
#  'methodical': [['method', 'n'], ['ical', 'n', 'adj']],
#  'methodize': [['method', 'n'], ['ize', 'n', 'v']],
#  'methodology': [['method', 'n'], ['logy', 'n', 'n']],
#  'methods': [['method', 'n'], ['s', 'n', 'n']],
#  'momentary': [['moment', 'n'], ['ary', 'n', 'adj']],
#  'moments': [['moment', 'n'], ['s', 'n', 'n']],
#  'momentum': [['moment', 'n'], ['um', 'n', 'n']],
#  'musical': [['music', 'n'], ['al', 'n', 'adj']],
#  'musician': [['music', 'n'], ['ian', 'n', 'n']],
#  'musics': [['music', 'n'], ['s', 'n', 'n']],
#  'national': [['nation', 'n'], ['al', 'n', 'n']],
#  'nations': [['nation', 'n'], ['s', 'n', 'n']],
#  'nightly': [['night', 'n'], ['ly', 'n', 'adj']],
#  'nights': [['night', 'n'], ['s', 'n', 'n']],
#  'officer': [['office', 'n'], ['er', 'n', 'n']],
#  'offices': [['office', 'n'], ['s', 'n', 'n']],
#  'problematic': [['problem', 'n'], ['atic', 'n', 'adj']],
#  'problems': [['problem', 'n'], ['s', 'n', 'n']],
#  'producer': [['produce', 'v'], ['er', 'v', 'n']],
#  'product': [['produce', 'v'], ['t', 'v', 'adj']],
#  'production': [['produce', 'v'], ['tion', 'v', 'n']],
#  'productive': [['produce', 'v'], ['ive', 'v', 'adj']],
#  'raced': [['race', 'v'], ['ed', 'v', 'v']],
#  'racer': [['race', 'n'], ['er', 'n', 'n']],
#  'races': [['race', 'n'], ['s', 'n', 'n']],
#  'reacher': [['reach', 'v'], ['er', 'v', 'n']],
#  'reaches': [['reach', 'v'], ['s', 'v', 'v']],
#  'reaching': [['reach', 'v'], ['ing', 'v', 'n']],
#  'received': [['receive', 'v'], ['ed', 'v', 'v']],
#  'receiver': [['receive', 'v'], ['er', 'v', 'n']],
#  'receives': [['receive', 'v'], ['s', 'v', 'v']],
#  'receiving': [['receive', 'v'], ['ing', 'v', 'n']],
#  'saying': [['say', 'v'], ['ing', 'v', 'n']],
#  'says': [['say', 'v'], ['s', 'v', 'v']],
#  'sciences': [['science', 'n'], ['s', 'n', 'n']],
#  'seeing': [['see', 'v'], ['ing', 'v', 'n']],
#  'sees': [['see', 'v'], ['s', 'v', 'v']],
#  'served': [['serve', 'v'], ['ed', 'v', 'v']],
#  'server': [['serve', 'v'], ['er', 'v', 'n']],
#  'serves': [['serve', 'v'], ['s', 'v', 'v']],
#  'sets': [['set', 'v'], ['s', 'v', 'v']],
#  'setting': [['set', 'v'], ['ing', 'v', 'n']],
#  'shortage': [['short', 'adj'], ['age', 'adj', 'n']],
#  'shorten': [['short', 'adj'], ['en', 'adj', 'v']],
#  'shorter': [['short', 'adj'], ['er', 'adj', 'adj']],
#  'shortest': [['short', 'adj'], ['est', 'adj', 'adj']],
#  'shortly': [['short', 'adj'], ['ly', 'adj', 'adv']],
#  'showed': [['show', 'v'], ['ed', 'v', 'v']],
#  'shows': [['show', 'v'], ['s', 'v', 'v']],
#  'showy': [['show', 'v'], ['y', 'v', 'adj']],
#  'simpleness': [['simple', 'adj'], ['ness', 'adj', 'n']],
#  'simpler': [['simple', 'adj'], ['er', 'adj', 'adj']],
#  'simplest': [['simple', 'adj'], ['est', 'adj', 'adj']],
#  'simplicity': [['simple', 'adj'], ['city', 'adj', 'n']],
#  'slower': [['slow', 'adj'], ['er', 'adj', 'adj']],
#  'slowest': [['slow', 'adj'], ['est', 'adj', 'adj']],
#  'slowly': [['slow', 'adj'], ['ly', 'adj', 'adv']],
#  'smaller': [['small', 'adj'], ['er', 'adj', 'adj']],
#  'smallest': [['small', 'adj'], ['est', 'adj', 'adj']],
#  'smallish': [['small', 'adj'], ['ish', 'adj', 'adj']],
#  'smallness': [['small', 'adj'], ['ness', 'adj', 'n']],
#  'smarter': [['smart', 'adj'], ['er', 'adj', 'adj']],
#  'smartest': [['smart', 'adj'], ['est', 'adj', 'adj']],
#  'smartly': [['smart', 'adj'], ['ly', 'adj', 'adv']],
#  'smartness': [['smart', 'adj'], ['ness', 'adj', 'n']],
#  'soften': [['soft', 'adj'], ['en', 'adj', 'v']],
#  'softer': [['soft', 'adj'], ['er', 'adj', 'adj']],
#  'softest': [['soft', 'adj'], ['est', 'adj', 'adj']],
#  'softly': [['soft', 'adj'], ['ly', 'adj', 'adv']],
#  'softness': [['soft', 'adj'], ['ness', 'adj', 'n']],
#  'soups': [['soup', 'n'], ['s', 'n', 'n']],
#  'stories': [['story', 'n'], ['s', 'n', 'n']],
#  'storying': [['story', 'n'], ['ing', 'n', 'n']],
#  'stronger': [['strong', 'adj'], ['er', 'adj', 'adj']],
#  'strongest': [['strong', 'adj'], ['est', 'adj', 'adj']],
#  'strongly': [['strong', 'adj'], ['ly', 'adj', 'adv']],
#  'systematic': [['system', 'n'], ['atic', 'n', 'adj']],
#  'systemize': [['system', 'n'], ['ize', 'n', 'v']],
#  'systems': [['system', 'n'], ['s', 'n', 'n']],
#  'taller': [['tall', 'adj'], ['er', 'adj', 'adj']],
#  'tallest': [['tall', 'adj'], ['est', 'adj', 'adj']],
#  'tallness': [['tall', 'adj'], ['ness', 'adj', 'n']],
#  'teacher': [['teach', 'v'], ['er', 'v', 'n']],
#  'teaches': [['teach', 'v'], ['s', 'v', 'v']],
#  'teaching': [['teach', 'v'], ['ing', 'v', 'n']],
#  'theoretical': [['theory', 'n'], ['atical', 'n', 'adj']],
#  'theories': [['theory', 'n'], ['s', 'n', 'n']],
#  'things': [['thing', 'n'], ['s', 'n', 'n']],
#  'thinkable': [['think', 'v'], ['able', 'v', 'adj']],
#  'thinking': [['think', 'v'], ['ing', 'v', 'v']],
#  'thinks': [['think', 'v'], ['s', 'v', 'v']],
#  'toughen': [['tough', 'adj'], ['en', 'adj', 'v']],
#  'tougher': [['tough', 'adj'], ['er', 'adj', 'adj']],
#  'toughest': [['tough', 'adj'], ['est', 'adj', 'adj']],
#  'toughly': [['tough', 'adj'], ['ly', 'adj', 'adv']],
#  'toughness': [['tough', 'adj'], ['ness', 'adj', 'n']],
#  'videoing': [['video', 'n'], ['ing', 'n', 'v']],
#  'videos': [['video', 'n'], ['s', 'n', 'n']],
#  'weaken': [['weak', 'adj'], ['en', 'adj', 'v']],
#  'weaker': [['weak', 'adj'], ['er', 'adj', 'adj']],
#  'weakest': [['weak', 'adj'], ['est', 'adj', 'adj']],
#  'weakly': [['weak', 'adj'], ['ly', 'adj', 'adv']],
#  'weakness': [['weak', 'adj'], ['ness', 'adj', 'n']],
#  'woods': [['wood', 'n'], ['s', 'n', 'n']],
#  'woody': [['wood', 'n'], ['y', 'n', 'adj']],
#  'worlds': [['world', 'n'], ['s', 'n', 'n']],
#  'worldwide': [['world', 'n'], ['wide', 'n', 'adj']],
#  'yearly': [['year', 'n'], ['ly', 'n', 'adv']],
#  'years': [['year', 'n'], ['s', 'n', 'n']]}

# %%
suffixes = dict()

file = open("Suffixes.txt", "r")
for line in file.readlines():
    line = line.split()
    if line[0] not in suffixes:
        suffixes[line[0]] = [line[1:]]
    else:
        suffixes[line[0]].append(line[1:])

# %%
suffixes
# Out:
# {'age': [['s', 'n', 'n']],
#  'al': [['ly', 'adj', 'adv'],
#   ['ist', 'n', 'n'],
#   ['ize', 'n', 'v'],
#   ['izm', 'n', 'n'],
#   ['logy', 'n', 'n'],
#   ['istic', 'n', 'adj'],
#   ['s', 'n', 'n']],
#  'ance': [['s', 'n', 'n']],
#  'ary': [['ly', 'adj', 'adv']],
#  'ate': [['ly', 'adj', 'adv'], ['ness', 'adj', 'n']],
#  'atic': [['al', 'n', 'adj']],
#  'ation': [['al', 'n', 'adj']],
#  'en': [['s', 'v', 'v'], ['ing', 'v', 'v'], ['ed', 'v', 'v']],
#  'er': [['s', 'n', 'n'], ['s', 'n', 'n']],
#  'ful': [['ly', 'adj', 'adv'],
#   ['ness', 'adj', 'n'],
#   ['ly', 'adj', 'adv'],
#   ['ness', 'adj', 'n']],
#  'ian': [['s', 'n', 'n']],
#  'ical': [['ly', 'adj', 'adv']],
#  'ine': [['er', 'v', 'n'],
#   ['s', 'v', 'v'],
#   ['ation', 'v', 'n'],
#   ['ed', 'v', 'v'],
#   ['ing', 'v', 'v']],
#  'ish': [['ly', 'adj', 'adv']],
#  'ive': [['ity', 'adj', 'n'], ['ness', 'adj', 'n'], ['ly', 'adj', 'adv']],
#  'ize': [['ation', 'v', 'n'],
#   ['ing', 'v', 'n'],
#   ['ed', 'v', 'n'],
#   ['er', 'v', 'n'],
#   ['ed', 'v', 'v'],
#   ['ing', 'v', 'v'],
#   ['able', 'v', 'adj']],
#  'less': [['ness', 'adj', 'n'], ['ly', 'adj', 'adv']],
#  'logy': [['s', 'n', 'n'], ['ical', 'n', 'adj']],
#  'ly': [['er', 'adj', 'adj'], ['est', 'adj', 'adj'], ['ness', 'adj', 'n']],
#  'ment': [['s', 'n', 'n']],
#  'ness': [['s', 'n', 'n']],
#  'or': [['s', 'n', 'n']],
#  'ship': [['s', 'n', 'n']],
#  'th': [['s', 'n', 'n']],
#  'ual': [['ly', 'adj', 'adv']],
#  'y': [['s', 'n', 'n']],
#  'yer': [['s', 'n', 'n']]}

# %%
secondDerivedWords = dict()

# makes orthographic checks
# for e-deletion, e-insertion, y-replacement
# returns the correctly spelled form
def orthochechker(word,suffix):
    finalword=""
    suffixedellist=["ing","ed","ation","able","ive","ion","er","ist","t"]
    stemeinslist=["s","x","z"]
    yrepilist=["ly","er","est","ical","ed"]
    yrepielist=["s"]
    #e deletion
    if word[len(word)-1]=="e":
        if suffix in suffixedellist:
            for a in range(0,len(word)-1):
                finalword+= word[a] 
            finalword+=suffix
    #e insertion
    elif word[len(word)-1]in stemeinslist:
        if suffix=="s":
            finalword=word+"e"
            finalword+=suffix
    #y replacement
    elif word[len(word)-1]=="y":
        if suffix in yrepilist:
            for a in range(0,len(word)-1):
                finalword+= word[a]
            if suffix != 'ical':
                finalword+="i"
            finalword+=suffix
        elif suffix in yrepielist:
            for a in range(0,len(word)-1):
                finalword+= word[a] 
            finalword+="ie"
            finalword+=suffix
            
    if finalword == "":
        return word+suffix
    else:
        return finalword
    
def addSuffix(word, wordSuffixes):
    lastSuffix = wordSuffixes[-1][0]
    lastSuffixPOS = wordSuffixes[-1][-1]
    if lastSuffix in suffixes:
        for extraSuffixes in suffixes[lastSuffix]:
            if extraSuffixes[1] == lastSuffixPOS:
                newWord = orthochechker(word, extraSuffixes[0])
                secondDerivedWords[newWord] = wordSuffixes + [extraSuffixes]
                if len(secondDerivedWords[newWord]) < 4:
                    addSuffix(newWord, secondDerivedWords[newWord])

# %%
for word, wordSuffixes in firstDerivedWords.items():
    addSuffix(word, wordSuffixes)
    
derivedWords = {**firstDerivedWords, **secondDerivedWords}

# %%
derivedWords
# Out:
# {'appearance': [['appear', 'v'], ['ance', 'v', 'n']],
#  'appearances': [['appear', 'v'], ['ance', 'v', 'n'], ['s', 'n', 'n']],
#  'appearing': [['appear', 'v'], ['ing', 'v', 'v']],
#  'appears': [['appear', 'v'], ['s', 'v', 'v']],
#  'areal': [['area', 'n'], ['al', 'n', 'adj']],
#  'areally': [['area', 'n'], ['al', 'n', 'adj'], ['ly', 'adj', 'adv']],
#  'areas': [['area', 'n'], ['s', 'n', 'n']],
#  'armies': [['army', 'n'], ['s', 'n', 'n']],
#  'articled': [['article', 'n'], ['ed', 'n', 'adj']],
#  'articles': [['article', 'n'], ['s', 'n', 'n']],
#  'artist': [['art', 'n'], ['ist', 'n', 'n']],
#  'arts': [['art', 'n'], ['s', 'n', 'n']],
#  'becomes': [['become', 'v'], ['s', 'v', 'v']],
#  'beginner': [['begin', 'v'], ['n', 'v', 'n']],
#  'beginning': [['begin', 'v'], ['ing', 'v', 'n']],
#  'begins': [['begin', 'v'], ['s', 'v', 'v']],
#  'believed': [['believe', 'v'], ['ed', 'v', 'v']],
#  'believer': [['believe', 'v'], ['er', 'v', 'n']],
#  'believers': [['believe', 'v'], ['er', 'v', 'n'], ['s', 'n', 'n']],
#  'believes': [['believe', 'v'], ['s', 'v', 'v']],
#  'bigger': [['big', 'adj'], ['er', 'adj', 'adj']],
#  'biggest': [['big', 'adj'], ['est', 'adj', 'adj']],
#  'bigness': [['big', 'adj'], ['ness', 'adj', 'n']],
#  'bignesses': [['big', 'adj'], ['ness', 'adj', 'n'], ['s', 'n', 'n']],
#  'birds': [['bird', 'n'], ['s', 'n', 'n']],
#  'builder': [['build', 'v'], ['er', 'v', 'n']],
#  'builders': [['build', 'v'], ['er', 'v', 'n'], ['s', 'n', 'n']],
#  'building': [['build', 'v'], ['ing', 'v', 'n']],
#  'builds': [['build', 'v'], ['s', 'v', 'v']],
#  'calculatable': [['calculate', 'v'], ['able', 'v', 'adj']],
#  'calculated': [['calculate', 'v'], ['ed', 'v', 'v']],
#  'calculater': [['calculate', 'v'], ['er', 'v', 'n']],
#  'calculaters': [['calculate', 'v'], ['er', 'v', 'n'], ['s', 'n', 'n']],
#  'calculation': [['calculate', 'v'], ['ation', 'v', 'n']],
#  'calculational': [['calculate', 'v'],
#   ['ation', 'v', 'n'],
#   ['al', 'n', 'adj']],
#  'calculationally': [['calculate', 'v'],
#   ['ation', 'v', 'n'],
#   ['al', 'n', 'adj'],
#   ['ly', 'adj', 'adv']],
#  'cameras': [['camera', 'n'], ['s', 'n', 'n']],
#  'clearer': [['clear', 'adj'], ['er', 'adj', 'adj']],
#  'clearest': [['clear', 'adj'], ['est', 'adj', 'adj']],
#  'clearly': [['clear', 'adj'], ['ly', 'adj', 'adv']],
#  'clearness': [['clear', 'adj'], ['ness', 'adj', 'n']],
#  'clearnesses': [['clear', 'adj'], ['ness', 'adj', 'n'], ['s', 'n', 'n']],
#  'computable': [['compute', 'v'], ['able', 'v', 'adj']],
#  'computation': [['compute', 'v'], ['ation', 'v', 'n']],
#  'computational': [['compute', 'v'], ['ation', 'v', 'n'], ['al', 'n', 'adj']],
#  'computationally': [['compute', 'v'],
#   ['ation', 'v', 'n'],
#   ['al', 'n', 'adj'],
#   ['ly', 'adj', 'adv']],
#  'computer': [['compute', 'v'], ['er', 'v', 'n']],
#  'computers': [['compute', 'v'], ['er', 'v', 'n'], ['s', 'n', 'n']],
#  'computizable': [['compute', 'v'], ['ize', 'v', 'v'], ['able', 'v', 'adj']],
#  'computization': [['compute', 'v'], ['ize', 'v', 'v'], ['ation', 'v', 'n']],
#  'computizational': [['compute', 'v'],
#   ['ize', 'v', 'v'],
#   ['ation', 'v', 'n'],
#   ['al', 'n', 'adj']],
#  'computize': [['compute', 'v'], ['ize', 'v', 'v']],
#  'computized': [['compute', 'v'], ['ize', 'v', 'v'], ['ed', 'v', 'v']],
#  'computizer': [['compute', 'v'], ['ize', 'v', 'v'], ['er', 'v', 'n']],
#  'computizers': [['compute', 'v'],
#   ['ize', 'v', 'v'],
#   ['er', 'v', 'n'],
#   ['s', 'n', 'n']],
#  'computizing': [['compute', 'v'], ['ize', 'v', 'v'], ['ing', 'v', 'v']],
#  'considerate': [['consider', 'v'], ['ate', 'v', 'adj']],
#  'considerately': [['consider', 'v'],
#   ['ate', 'v', 'adj'],
#   ['ly', 'adj', 'adv']],
#  'considerateness': [['consider', 'v'],
#   ['ate', 'v', 'adj'],
#   ['ness', 'adj', 'n']],
#  'consideratenesses': [['consider', 'v'],
#   ['ate', 'v', 'adj'],
#   ['ness', 'adj', 'n'],
#   ['s', 'n', 'n']],
#  'consideration': [['consider', 'v'], ['ation', 'v', 'n']],
#  'considerational': [['consider', 'v'],
#   ['ation', 'v', 'n'],
#   ['al', 'n', 'adj']],
#  'considerationally': [['consider', 'v'],
#   ['ation', 'v', 'n'],
#   ['al', 'n', 'adj'],
#   ['ly', 'adj', 'adv']],
#  'considering': [['consider', 'v'], ['ing', 'v', 'v']],
#  'considers': [['consider', 'v'], ['s', 'v', 'v']],
#  'consumed': [['consume', 'v'], ['ed', 'v', 'v']],
#  'consumer': [['consume', 'v'], ['er', 'v', 'n']],
#  'consumers': [['consume', 'v'], ['er', 'v', 'n'], ['s', 'n', 'n']],
#  'consumes': [['consume', 'v'], ['s', 'v', 'v']],
#  'consuming': [['consume', 'v'], ['ing', 'v', 'n']],
#  'controled': [['control', 'n'], ['ed', 'n', 'n']],
#  'controllable': [['control', 'n'], ['able', 'n', 'adj']],
#  'controlled': [['control', 'v'], ['ed', 'v', 'v']],
#  'controller': [['control', 'n'], ['er', 'n', 'n']],
#  'controllers': [['control', 'n'], ['er', 'n', 'n'], ['s', 'n', 'n']],
#  'controlling': [['control', 'v'], ['ing', 'v', 'v']],
#  'controls': [['control', 'n'], ['s', 'n', 'n']],
#  'died': [['die', 'v'], ['ed', 'v', 'v']],
#  'dies': [['die', 'v'], ['s', 'v', 'v']],
#  'difficulties': [['difficult', 'adj'], ['y', 'adj', 'n'], ['s', 'n', 'n']],
#  'difficultly': [['difficult', 'adj'], ['ly', 'adj', 'adv']],
#  'difficulty': [['difficult', 'adj'], ['y', 'adj', 'n']],
#  'disks': [['disk', 'n'], ['s', 'n', 'n']],
#  'easier': [['easy', 'adj'], ['er', 'adj', 'adj']],
#  'easiest': [['easy', 'adj'], ['est', 'adj', 'adj']],
#  'easily': [['easy', 'adj'], ['ly', 'adj', 'adv']],
#  'eventful': [['event', 'n'], ['ful', 'n', 'adj']],
#  'eventfully': [['event', 'n'], ['ful', 'n', 'adj'], ['ly', 'adj', 'adv']],
#  'eventfulness': [['event', 'n'], ['ful', 'n', 'adj'], ['ness', 'adj', 'n']],
#  'eventfulnesses': [['event', 'n'],
#   ['ful', 'n', 'adj'],
#   ['ness', 'adj', 'n'],
#   ['s', 'n', 'n']],
#  'events': [['event', 'n'], ['s', 'n', 'n']],
#  'eventual': [['event', 'n'], ['ual', 'n', 'adj']],
#  'eventually': [['event', 'n'], ['ual', 'n', 'adj'], ['ly', 'adj', 'adv']],
#  'examination': [['exam', 'n'], ['ine', 'n', 'v'], ['ation', 'v', 'n']],
#  'examinational': [['exam', 'n'],
#   ['ine', 'n', 'v'],
#   ['ation', 'v', 'n'],
#   ['al', 'n', 'adj']],
#  'examine': [['exam', 'n'], ['ine', 'n', 'v']],
#  'examined': [['exam', 'n'], ['ine', 'n', 'v'], ['ed', 'v', 'v']],
#  'examiner': [['exam', 'n'], ['ine', 'n', 'v'], ['er', 'v', 'n']],
#  'examiners': [['exam', 'n'],
#   ['ine', 'n', 'v'],
#   ['er', 'v', 'n'],
#   ['s', 'n', 'n']],
#  'examines': [['exam', 'n'], ['ine', 'n', 'v'], ['s', 'v', 'v']],
#  'examining': [['exam', 'n'], ['ine', 'n', 'v'], ['ing', 'v', 'v']],
#  'exams': [['exam', 'n'], ['s', 'n', 'n']],
#  'faction': [['fact', 'n'], ['ion', 'n', 'n']],
#  'factive': [['fact', 'n'], ['ive', 'n', 'adj']],
#  'factiveity': [['fact', 'n'], ['ive', 'n', 'adj'], ['ity', 'adj', 'n']],
#  'factively': [['fact', 'n'], ['ive', 'n', 'adj'], ['ly', 'adj', 'adv']],
#  'factiveness': [['fact', 'n'], ['ive', 'n', 'adj'], ['ness', 'adj', 'n']],
#  'factivenesses': [['fact', 'n'],
#   ['ive', 'n', 'adj'],
#   ['ness', 'adj', 'n'],
#   ['s', 'n', 'n']],
#  'facts': [['fact', 'n'], ['s', 'n', 'n']],
#  'factual': [['fact', 'n'], ['ual', 'n', 'adj']],
#  'factually': [['fact', 'n'], ['ual', 'n', 'adj'], ['ly', 'adj', 'adv']],
#  'families': [['family', 'n'], ['s', 'n', 'n']],
#  'fasten': [['fast', 'adj'], ['en', 'adj', 'v']],
#  'fastened': [['fast', 'adj'], ['en', 'adj', 'v'], ['ed', 'v', 'v']],
#  'fastening': [['fast', 'adj'], ['en', 'adj', 'v'], ['ing', 'v', 'v']],
#  'fastens': [['fast', 'adj'], ['en', 'adj', 'v'], ['s', 'v', 'v']],
#  'faster': [['fast', 'adj'], ['er', 'adj', 'adj']],
#  'fastest': [['fast', 'adj'], ['est', 'adj', 'adj']],
#  'feeler': [['feel', 'v'], ['er', 'v', 'n']],
#  'feelers': [['feel', 'v'], ['er', 'v', 'n'], ['s', 'n', 'n']],
#  'feeling': [['feel', 'v'], ['ing', 'v', 'n']],
#  'foods': [['food', 'n'], ['s', 'n', 'n']],
#  'gets': [['get', 'v'], ['s', 'v', 'v']],
#  'getting': [['get', 'v'], ['ing', 'v', 'v']],
#  'growing': [['grow', 'v'], ['ing', 'v', 'v']],
#  'grows': [['grow', 'v'], ['s', 'v', 'v']],
#  'growth': [['grow', 'v'], ['th', 'v', 'n']],
#  'growths': [['grow', 'v'], ['th', 'v', 'n'], ['s', 'n', 'n']],
#  'harden': [['hard', 'adj'], ['en', 'adj', 'v']],
#  'hardened': [['hard', 'adj'], ['en', 'adj', 'v'], ['ed', 'v', 'v']],
#  'hardening': [['hard', 'adj'], ['en', 'adj', 'v'], ['ing', 'v', 'v']],
#  'hardens': [['hard', 'adj'], ['en', 'adj', 'v'], ['s', 'v', 'v']],
#  'harder': [['hard', 'adj'], ['er', 'adj', 'adj']],
#  'hardest': [['hard', 'adj'], ['est', 'adj', 'adj']],
#  'hardly': [['hard', 'adj'], ['ly', 'adj', 'adv']],
#  'hardness': [['hard', 'adj'], ['ness', 'adj', 'n']],
#  'hardnesses': [['hard', 'adj'], ['ness', 'adj', 'n'], ['s', 'n', 'n']],
#  'hardship': [['hard', 'adj'], ['ship', 'adj', 'n']],
#  'hardships': [['hard', 'adj'], ['ship', 'adj', 'n'], ['s', 'n', 'n']],
#  'hearer': [['hear', 'v'], ['er', 'v', 'n']],
#  'hearers': [['hear', 'v'], ['er', 'v', 'n'], ['s', 'n', 'n']],
#  'hearing': [['hear', 'v'], ['ing', 'v', 'n']],
#  'hears': [['hear', 'v'], ['s', 'v', 'v']],
#  'helped': [['help', 'v'], ['ed', 'v', 'v']],
#  'helper': [['help', 'n'], ['er', 'n', 'n']],
#  'helpers': [['help', 'n'], ['er', 'n', 'n'], ['s', 'n', 'n']],
#  'helpful': [['help', 'n'], ['ful', 'n', 'adj']],
#  'helpfully': [['help', 'n'], ['ful', 'n', 'adj'], ['ly', 'adj', 'adv']],
#  'helpfulness': [['help', 'n'], ['ful', 'n', 'adj'], ['ness', 'adj', 'n']],
#  'helpfulnesses': [['help', 'n'],
#   ['ful', 'n', 'adj'],
#   ['ness', 'adj', 'n'],
#   ['s', 'n', 'n']],
#  'helpless': [['help', 'n'], ['less', 'n', 'adj']],
#  'helplessly': [['help', 'n'], ['less', 'n', 'adj'], ['ly', 'adj', 'adv']],
#  'helplessness': [['help', 'n'], ['less', 'n', 'adj'], ['ness', 'adj', 'n']],
#  'helplessnesses': [['help', 'n'],
#   ['less', 'n', 'adj'],
#   ['ness', 'adj', 'n'],
#   ['s', 'n', 'n']],
#  'helps': [['help', 'n'], ['s', 'n', 'n']],
#  'higher': [['high', 'adj'], ['er', 'adj', 'adj']],
#  'highest': [['high', 'adj'], ['est', 'adj', 'adj']],
#  'highly': [['high', 'adj'], ['ly', 'adj', 'adv']],
#  'highness': [['high', 'adj'], ['ness', 'adj', 'n']],
#  'highnesses': [['high', 'adj'], ['ness', 'adj', 'n'], ['s', 'n', 'n']],
#  'historical': [['history', 'n'], ['ical', 'n', 'adj']],
#  'historically': [['history', 'n'],
#   ['ical', 'n', 'adj'],
#   ['ly', 'adj', 'adv']],
#  'histories': [['history', 'n'], ['s', 'n', 'n']],
#  'hugely': [['huge', 'adj'], ['ly', 'adj', 'adv']],
#  'hugeness': [['huge', 'adj'], ['ness', 'adj', 'n']],
#  'hugenesses': [['huge', 'adj'], ['ness', 'adj', 'n'], ['s', 'n', 'n']],
#  'ideal': [['idea', 'n'], ['al', 'n', 'n']],
#  'idealist': [['idea', 'n'], ['al', 'n', 'n'], ['ist', 'n', 'n']],
#  'idealistic': [['idea', 'n'], ['al', 'n', 'n'], ['istic', 'n', 'adj']],
#  'idealizable': [['idea', 'n'],
#   ['al', 'n', 'n'],
#   ['ize', 'n', 'v'],
#   ['able', 'v', 'adj']],
#  'idealization': [['idea', 'n'],
#   ['al', 'n', 'n'],
#   ['ize', 'n', 'v'],
#   ['ation', 'v', 'n']],
#  'idealize': [['idea', 'n'], ['al', 'n', 'n'], ['ize', 'n', 'v']],
#  'idealized': [['idea', 'n'],
#   ['al', 'n', 'n'],
#   ['ize', 'n', 'v'],
#   ['ed', 'v', 'v']],
#  'idealizer': [['idea', 'n'],
#   ['al', 'n', 'n'],
#   ['ize', 'n', 'v'],
#   ['er', 'v', 'n']],
#  'idealizing': [['idea', 'n'],
#   ['al', 'n', 'n'],
#   ['ize', 'n', 'v'],
#   ['ing', 'v', 'v']],
#  'idealizm': [['idea', 'n'], ['al', 'n', 'n'], ['izm', 'n', 'n']],
#  'ideallogical': [['idea', 'n'],
#   ['al', 'n', 'n'],
#   ['logy', 'n', 'n'],
#   ['ical', 'n', 'adj']],
#  'ideallogies': [['idea', 'n'],
#   ['al', 'n', 'n'],
#   ['logy', 'n', 'n'],
#   ['s', 'n', 'n']],
#  'ideallogy': [['idea', 'n'], ['al', 'n', 'n'], ['logy', 'n', 'n']],
#  'ideals': [['idea', 'n'], ['al', 'n', 'n'], ['s', 'n', 'n']],
#  'ideas': [['idea', 'n'], ['s', 'n', 'n']],
#  'investing': [['invest', 'v'], ['ing', 'v', 'n']],
#  'investment': [['invest', 'v'], ['ment', 'v', 'n']],
#  'investments': [['invest', 'v'], ['ment', 'v', 'n'], ['s', 'n', 'n']],
#  'investor': [['invest', 'v'], ['or', 'v', 'n']],
#  'investors': [['invest', 'v'], ['or', 'v', 'n'], ['s', 'n', 'n']],
#  'lawful': [['law', 'n'], ['ful', 'n', 'adj']],
#  'lawfully': [['law', 'n'], ['ful', 'n', 'adj'], ['ly', 'adj', 'adv']],
#  'lawfulness': [['law', 'n'], ['ful', 'n', 'adj'], ['ness', 'adj', 'n']],
#  'lawfulnesses': [['law', 'n'],
#   ['ful', 'n', 'adj'],
#   ['ness', 'adj', 'n'],
#   ['s', 'n', 'n']],
#  'lawless': [['law', 'n'], ['less', 'n', 'adj']],
#  'lawlessly': [['law', 'n'], ['less', 'n', 'adj'], ['ly', 'adj', 'adv']],
#  'lawlessness': [['law', 'n'], ['less', 'n', 'adj'], ['ness', 'adj', 'n']],
#  'lawlessnesses': [['law', 'n'],
#   ['less', 'n', 'adj'],
#   ['ness', 'adj', 'n'],
#   ['s', 'n', 'n']],
#  'laws': [['law', 'n'], ['s', 'n', 'n']],
#  'lawyer': [['law', 'n'], ['yer', 'n', 'n']],
#  'lawyers': [['law', 'n'], ['yer', 'n', 'n'], ['s', 'n', 'n']],
#  'libraries': [['library', 'n'], ['s', 'n', 'n']],
#  'lived': [['live', 'v'], ['ed', 'v', 'v']],
#  'livelier': [['live', 'v'], ['ly', 'v', 'adj'], ['er', 'adj', 'adj']],
#  'liveliest': [['live', 'v'], ['ly', 'v', 'adj'], ['est', 'adj', 'adj']],
#  'lively': [['live', 'v'], ['ly', 'v', 'adj']],
#  'livelyness': [['live', 'v'], ['ly', 'v', 'adj'], ['ness', 'adj', 'n']],
#  'livelynesses': [['live', 'v'],
#   ['ly', 'v', 'adj'],
#   ['ness', 'adj', 'n'],
#   ['s', 'n', 'n']],
#  'lives': [['live', 'v'], ['s', 'v', 'v']],
#  'longer': [['long', 'adj'], ['er', 'adj', 'adj']],
#  'longest': [['long', 'adj'], ['est', 'adj', 'adj']],
#  'longevity': [['long', 'adj'], ['evity', 'adj', 'n']],
#  'longish': [['long', 'adj'], ['ish', 'adj', 'adj']],
#  'longishly': [['long', 'adj'], ['ish', 'adj', 'adj'], ['ly', 'adj', 'adv']],
#  'looked': [['look', 'v'], ['ed', 'v', 'v']],
#  'looking': [['look', 'v'], ['ing', 'v', 'n']],
#  'looks': [['look', 'v'], ['s', 'v', 'v']],
#  'loser': [['lose', 'v'], ['er', 'v', 'n']],
#  'losers': [['lose', 'v'], ['er', 'v', 'n'], ['s', 'n', 'n']],
#  'loses': [['lose', 'v'], ['s', 'v', 'v']],
#  'losing': [['lose', 'v'], ['ing', 'v', 'v']],
#  'lower': [['low', 'adj'], ['er', 'adj', 'adj']],
#  'lowest': [['low', 'adj'], ['est', 'adj', 'adj']],
#  'lowly': [['low', 'adj'], ['ly', 'adj', 'adv']],
#  'lowness': [['low', 'adj'], ['ness', 'adj', 'n']],
#  'lownesses': [['low', 'adj'], ['ness', 'adj', 'n'], ['s', 'n', 'n']],
#  'maker': [['make', 'v'], ['r', 'v', 'n']],
#  'makes': [['make', 'v'], ['s', 'v', 'v']],
#  'mapped': [['map', 'v'], ['ed', 'v', 'v']],
#  'mapper': [['map', 'n'], ['er', 'n', 'n']],
#  'mappers': [['map', 'n'], ['er', 'n', 'n'], ['s', 'n', 'n']],
#  'mapping': [['map', 'v'], ['ing', 'v', 'n']],
#  'maps': [['map', 'n'], ['s', 'n', 'n']],
#  'maths': [['math', 'n'], ['s', 'n', 'n']],
#  'meadias': [['media', 'n'], ['s', 'n', 'n']],
#  'meaning': [['mean', 'v'], ['ing', 'v', 'n']],
#  'meatier': [['meat', 'n'], ['er', 'n', 'adj']],
#  'meatiest': [['meat', 'n'], ['est', 'n', 'adj']],
#  'meats': [['meat', 'n'], ['s', 'n', 'n']],
#  'meaty': [['meat', 'n'], ['y', 'n', 'adj']],
#  'mediative': [['media', 'n'], ['tive', 'n', 'adj']],
#  'methodical': [['method', 'n'], ['ical', 'n', 'adj']],
#  'methodically': [['method', 'n'], ['ical', 'n', 'adj'], ['ly', 'adj', 'adv']],
#  'methodizable': [['method', 'n'], ['ize', 'n', 'v'], ['able', 'v', 'adj']],
#  'methodization': [['method', 'n'], ['ize', 'n', 'v'], ['ation', 'v', 'n']],
#  'methodizational': [['method', 'n'],
#   ['ize', 'n', 'v'],
#   ['ation', 'v', 'n'],
#   ['al', 'n', 'adj']],
#  'methodize': [['method', 'n'], ['ize', 'n', 'v']],
#  'methodized': [['method', 'n'], ['ize', 'n', 'v'], ['ed', 'v', 'v']],
#  'methodizer': [['method', 'n'], ['ize', 'n', 'v'], ['er', 'v', 'n']],
#  'methodizers': [['method', 'n'],
#   ['ize', 'n', 'v'],
#   ['er', 'v', 'n'],
#   ['s', 'n', 'n']],
#  'methodizing': [['method', 'n'], ['ize', 'n', 'v'], ['ing', 'v', 'v']],
#  'methodological': [['method', 'n'], ['logy', 'n', 'n'], ['ical', 'n', 'adj']],
#  'methodologically': [['method', 'n'],
#   ['logy', 'n', 'n'],
#   ['ical', 'n', 'adj'],
#   ['ly', 'adj', 'adv']],
#  'methodologies': [['method', 'n'], ['logy', 'n', 'n'], ['s', 'n', 'n']],
#  'methodology': [['method', 'n'], ['logy', 'n', 'n']],
#  'methods': [['method', 'n'], ['s', 'n', 'n']],
#  'momentarily': [['moment', 'n'], ['ary', 'n', 'adj'], ['ly', 'adj', 'adv']],
#  'momentary': [['moment', 'n'], ['ary', 'n', 'adj']],
#  'moments': [['moment', 'n'], ['s', 'n', 'n']],
#  'momentum': [['moment', 'n'], ['um', 'n', 'n']],
#  'musical': [['music', 'n'], ['al', 'n', 'adj']],
#  'musically': [['music', 'n'], ['al', 'n', 'adj'], ['ly', 'adj', 'adv']],
#  'musician': [['music', 'n'], ['ian', 'n', 'n']],
#  'musicians': [['music', 'n'], ['ian', 'n', 'n'], ['s', 'n', 'n']],
#  'musics': [['music', 'n'], ['s', 'n', 'n']],
#  'national': [['nation', 'n'], ['al', 'n', 'n']],
#  'nationalist': [['nation', 'n'], ['al', 'n', 'n'], ['ist', 'n', 'n']],
#  'nationalistic': [['nation', 'n'], ['al', 'n', 'n'], ['istic', 'n', 'adj']],
#  'nationalizable': [['nation', 'n'],
#   ['al', 'n', 'n'],
#   ['ize', 'n', 'v'],
#   ['able', 'v', 'adj']],
#  'nationalization': [['nation', 'n'],
#   ['al', 'n', 'n'],
#   ['ize', 'n', 'v'],
#   ['ation', 'v', 'n']],
#  'nationalize': [['nation', 'n'], ['al', 'n', 'n'], ['ize', 'n', 'v']],
#  'nationalized': [['nation', 'n'],
#   ['al', 'n', 'n'],
#   ['ize', 'n', 'v'],
#   ['ed', 'v', 'v']],
#  'nationalizer': [['nation', 'n'],
#   ['al', 'n', 'n'],
#   ['ize', 'n', 'v'],
#   ['er', 'v', 'n']],
#  'nationalizing': [['nation', 'n'],
#   ['al', 'n', 'n'],
#   ['ize', 'n', 'v'],
#   ['ing', 'v', 'v']],
#  'nationalizm': [['nation', 'n'], ['al', 'n', 'n'], ['izm', 'n', 'n']],
#  'nationallogical': [['nation', 'n'],
#   ['al', 'n', 'n'],
#   ['logy', 'n', 'n'],
#   ['ical', 'n', 'adj']],
#  'nationallogies': [['nation', 'n'],
#   ['al', 'n', 'n'],
#   ['logy', 'n', 'n'],
#   ['s', 'n', 'n']],
#  'nationallogy': [['nation', 'n'], ['al', 'n', 'n'], ['logy', 'n', 'n']],
#  'nationals': [['nation', 'n'], ['al', 'n', 'n'], ['s', 'n', 'n']],
#  'nations': [['nation', 'n'], ['s', 'n', 'n']],
#  'nightlier': [['night', 'n'], ['ly', 'n', 'adj'], ['er', 'adj', 'adj']],
#  'nightliest': [['night', 'n'], ['ly', 'n', 'adj'], ['est', 'adj', 'adj']],
#  'nightly': [['night', 'n'], ['ly', 'n', 'adj']],
#  'nightlyness': [['night', 'n'], ['ly', 'n', 'adj'], ['ness', 'adj', 'n']],
#  'nightlynesses': [['night', 'n'],
#   ['ly', 'n', 'adj'],
#   ['ness', 'adj', 'n'],
#   ['s', 'n', 'n']],
#  'nights': [['night', 'n'], ['s', 'n', 'n']],
#  'officer': [['office', 'n'], ['er', 'n', 'n']],
#  'officers': [['office', 'n'], ['er', 'n', 'n'], ['s', 'n', 'n']],
#  'offices': [['office', 'n'], ['s', 'n', 'n']],
#  'problematic': [['problem', 'n'], ['atic', 'n', 'adj']],
#  'problems': [['problem', 'n'], ['s', 'n', 'n']],
#  'producer': [['produce', 'v'], ['er', 'v', 'n']],
#  'producers': [['produce', 'v'], ['er', 'v', 'n'], ['s', 'n', 'n']],
#  'product': [['produce', 'v'], ['t', 'v', 'adj']],
#  'production': [['produce', 'v'], ['tion', 'v', 'n']],
#  'productive': [['produce', 'v'], ['ive', 'v', 'adj']],
#  'productiveity': [['produce', 'v'], ['ive', 'v', 'adj'], ['ity', 'adj', 'n']],
#  'productively': [['produce', 'v'], ['ive', 'v', 'adj'], ['ly', 'adj', 'adv']],
#  'productiveness': [['produce', 'v'],
#   ['ive', 'v', 'adj'],
#   ['ness', 'adj', 'n']],
#  'productivenesses': [['produce', 'v'],
#   ['ive', 'v', 'adj'],
#   ['ness', 'adj', 'n'],
#   ['s', 'n', 'n']],
#  'raced': [['race', 'v'], ['ed', 'v', 'v']],
#  'racer': [['race', 'n'], ['er', 'n', 'n']],
#  'racers': [['race', 'n'], ['er', 'n', 'n'], ['s', 'n', 'n']],
#  'races': [['race', 'n'], ['s', 'n', 'n']],
#  'reacher': [['reach', 'v'], ['er', 'v', 'n']],
#  'reachers': [['reach', 'v'], ['er', 'v', 'n'], ['s', 'n', 'n']],
#  'reaches': [['reach', 'v'], ['s', 'v', 'v']],
#  'reaching': [['reach', 'v'], ['ing', 'v', 'n']],
#  'received': [['receive', 'v'], ['ed', 'v', 'v']],
#  'receiver': [['receive', 'v'], ['er', 'v', 'n']],
#  'receivers': [['receive', 'v'], ['er', 'v', 'n'], ['s', 'n', 'n']],
#  'receives': [['receive', 'v'], ['s', 'v', 'v']],
#  'receiving': [['receive', 'v'], ['ing', 'v', 'n']],
#  'saying': [['say', 'v'], ['ing', 'v', 'n']],
#  'says': [['say', 'v'], ['s', 'v', 'v']],
#  'sciences': [['science', 'n'], ['s', 'n', 'n']],
#  'seeing': [['see', 'v'], ['ing', 'v', 'n']],
#  'sees': [['see', 'v'], ['s', 'v', 'v']],
#  'served': [['serve', 'v'], ['ed', 'v', 'v']],
#  'server': [['serve', 'v'], ['er', 'v', 'n']],
#  'servers': [['serve', 'v'], ['er', 'v', 'n'], ['s', 'n', 'n']],
#  'serves': [['serve', 'v'], ['s', 'v', 'v']],
#  'sets': [['set', 'v'], ['s', 'v', 'v']],
#  'setting': [['set', 'v'], ['ing', 'v', 'n']],
#  'shortage': [['short', 'adj'], ['age', 'adj', 'n']],
#  'shortages': [['short', 'adj'], ['age', 'adj', 'n'], ['s', 'n', 'n']],
#  'shorten': [['short', 'adj'], ['en', 'adj', 'v']],
#  'shortened': [['short', 'adj'], ['en', 'adj', 'v'], ['ed', 'v', 'v']],
#  'shortening': [['short', 'adj'], ['en', 'adj', 'v'], ['ing', 'v', 'v']],
#  'shortens': [['short', 'adj'], ['en', 'adj', 'v'], ['s', 'v', 'v']],
#  'shorter': [['short', 'adj'], ['er', 'adj', 'adj']],
#  'shortest': [['short', 'adj'], ['est', 'adj', 'adj']],
#  'shortly': [['short', 'adj'], ['ly', 'adj', 'adv']],
#  'showed': [['show', 'v'], ['ed', 'v', 'v']],
#  'shows': [['show', 'v'], ['s', 'v', 'v']],
#  'showy': [['show', 'v'], ['y', 'v', 'adj']],
#  'simpleness': [['simple', 'adj'], ['ness', 'adj', 'n']],
#  'simplenesses': [['simple', 'adj'], ['ness', 'adj', 'n'], ['s', 'n', 'n']],
#  'simpler': [['simple', 'adj'], ['er', 'adj', 'adj']],
#  'simplest': [['simple', 'adj'], ['est', 'adj', 'adj']],
#  'simplicity': [['simple', 'adj'], ['city', 'adj', 'n']],
#  'slower': [['slow', 'adj'], ['er', 'adj', 'adj']],
#  'slowest': [['slow', 'adj'], ['est', 'adj', 'adj']],
#  'slowly': [['slow', 'adj'], ['ly', 'adj', 'adv']],
#  'smaller': [['small', 'adj'], ['er', 'adj', 'adj']],
#  'smallest': [['small', 'adj'], ['est', 'adj', 'adj']],
#  'smallish': [['small', 'adj'], ['ish', 'adj', 'adj']],
#  'smallishly': [['small', 'adj'], ['ish', 'adj', 'adj'], ['ly', 'adj', 'adv']],
#  'smallness': [['small', 'adj'], ['ness', 'adj', 'n']],
#  'smallnesses': [['small', 'adj'], ['ness', 'adj', 'n'], ['s', 'n', 'n']],
#  'smarter': [['smart', 'adj'], ['er', 'adj', 'adj']],
#  'smartest': [['smart', 'adj'], ['est', 'adj', 'adj']],
#  'smartly': [['smart', 'adj'], ['ly', 'adj', 'adv']],
#  'smartness': [['smart', 'adj'], ['ness', 'adj', 'n']],
#  'smartnesses': [['smart', 'adj'], ['ness', 'adj', 'n'], ['s', 'n', 'n']],
#  'soften': [['soft', 'adj'], ['en', 'adj', 'v']],
#  'softened': [['soft', 'adj'], ['en', 'adj', 'v'], ['ed', 'v', 'v']],
#  'softening': [['soft', 'adj'], ['en', 'adj', 'v'], ['ing', 'v', 'v']],
#  'softens': [['soft', 'adj'], ['en', 'adj', 'v'], ['s', 'v', 'v']],
#  'softer': [['soft', 'adj'], ['er', 'adj', 'adj']],
#  'softest': [['soft', 'adj'], ['est', 'adj', 'adj']],
#  'softly': [['soft', 'adj'], ['ly', 'adj', 'adv']],
#  'softness': [['soft', 'adj'], ['ness', 'adj', 'n']],
#  'softnesses': [['soft', 'adj'], ['ness', 'adj', 'n'], ['s', 'n', 'n']],
#  'soups': [['soup', 'n'], ['s', 'n', 'n']],
#  'stories': [['story', 'n'], ['s', 'n', 'n']],
#  'storying': [['story', 'n'], ['ing', 'n', 'n']],
#  'stronger': [['strong', 'adj'], ['er', 'adj', 'adj']],
#  'strongest': [['strong', 'adj'], ['est', 'adj', 'adj']],
#  'strongly': [['strong', 'adj'], ['ly', 'adj', 'adv']],
#  'systematic': [['system', 'n'], ['atic', 'n', 'adj']],
#  'systemizable': [['system', 'n'], ['ize', 'n', 'v'], ['able', 'v', 'adj']],
#  'systemization': [['system', 'n'], ['ize', 'n', 'v'], ['ation', 'v', 'n']],
#  'systemizational': [['system', 'n'],
#   ['ize', 'n', 'v'],
#   ['ation', 'v', 'n'],
#   ['al', 'n', 'adj']],
#  'systemize': [['system', 'n'], ['ize', 'n', 'v']],
#  'systemized': [['system', 'n'], ['ize', 'n', 'v'], ['ed', 'v', 'v']],
#  'systemizer': [['system', 'n'], ['ize', 'n', 'v'], ['er', 'v', 'n']],
#  'systemizers': [['system', 'n'],
#   ['ize', 'n', 'v'],
#   ['er', 'v', 'n'],
#   ['s', 'n', 'n']],
#  'systemizing': [['system', 'n'], ['ize', 'n', 'v'], ['ing', 'v', 'v']],
#  'systems': [['system', 'n'], ['s', 'n', 'n']],
#  'taller': [['tall', 'adj'], ['er', 'adj', 'adj']],
#  'tallest': [['tall', 'adj'], ['est', 'adj', 'adj']],
#  'tallness': [['tall', 'adj'], ['ness', 'adj', 'n']],
#  'tallnesses': [['tall', 'adj'], ['ness', 'adj', 'n'], ['s', 'n', 'n']],
#  'teacher': [['teach', 'v'], ['er', 'v', 'n']],
#  'teachers': [['teach', 'v'], ['er', 'v', 'n'], ['s', 'n', 'n']],
#  'teaches': [['teach', 'v'], ['s', 'v', 'v']],
#  'teaching': [['teach', 'v'], ['ing', 'v', 'n']],
#  'theoretical': [['theory', 'n'], ['atical', 'n', 'adj']],
#  'theories': [['theory', 'n'], ['s', 'n', 'n']],
#  'things': [['thing', 'n'], ['s', 'n', 'n']],
#  'thinkable': [['think', 'v'], ['able', 'v', 'adj']],
#  'thinking': [['think', 'v'], ['ing', 'v', 'v']],
#  'thinks': [['think', 'v'], ['s', 'v', 'v']],
#  'toughen': [['tough', 'adj'], ['en', 'adj', 'v']],
#  'toughened': [['tough', 'adj'], ['en', 'adj', 'v'], ['ed', 'v', 'v']],
#  'toughening': [['tough', 'adj'], ['en', 'adj', 'v'], ['ing', 'v', 'v']],
#  'toughens': [['tough', 'adj'], ['en', 'adj', 'v'], ['s', 'v', 'v']],
#  'tougher': [['tough', 'adj'], ['er', 'adj', 'adj']],
#  'toughest': [['tough', 'adj'], ['est', 'adj', 'adj']],
#  'toughly': [['tough', 'adj'], ['ly', 'adj', 'adv']],
#  'toughness': [['tough', 'adj'], ['ness', 'adj', 'n']],
#  'toughnesses': [['tough', 'adj'], ['ness', 'adj', 'n'], ['s', 'n', 'n']],
#  'videoing': [['video', 'n'], ['ing', 'n', 'v']],
#  'videos': [['video', 'n'], ['s', 'n', 'n']],
#  'weaken': [['weak', 'adj'], ['en', 'adj', 'v']],
#  'weakened': [['weak', 'adj'], ['en', 'adj', 'v'], ['ed', 'v', 'v']],
#  'weakening': [['weak', 'adj'], ['en', 'adj', 'v'], ['ing', 'v', 'v']],
#  'weakens': [['weak', 'adj'], ['en', 'adj', 'v'], ['s', 'v', 'v']],
#  'weaker': [['weak', 'adj'], ['er', 'adj', 'adj']],
#  'weakest': [['weak', 'adj'], ['est', 'adj', 'adj']],
#  'weakly': [['weak', 'adj'], ['ly', 'adj', 'adv']],
#  'weakness': [['weak', 'adj'], ['ness', 'adj', 'n']],
#  'weaknesses': [['weak', 'adj'], ['ness', 'adj', 'n'], ['s', 'n', 'n']],
#  'woods': [['wood', 'n'], ['s', 'n', 'n']],
#  'woody': [['wood', 'n'], ['y', 'n', 'adj']],
#  'worlds': [['world', 'n'], ['s', 'n', 'n']],
#  'worldwide': [['world', 'n'], ['wide', 'n', 'adj']],
#  'yearly': [['year', 'n'], ['ly', 'n', 'adv']],
#  'years': [['year', 'n'], ['s', 'n', 'n']]}

# %%
print("Number of Stems: %d" % (len(stems)))

print("Number of firstDerivedWords: %d" % (len(firstDerivedWords)))
print("Number of secondDerivedWords: %d" % (len(secondDerivedWords)))
print("Number of derivedWords: %d" % (len(derivedWords)))
print()
print("Total possible words: %d" % (len(derivedWords)+len(stems)))
# Out:
# Number of Stems: 99
# Number of firstDerivedWords: 252
# Number of secondDerivedWords: 164
# Number of derivedWords: 416
#
# Total possible words: 515

# %%
def surfaceLex(word):
    if word in stems:
        wordPOS = stems[word][0]
        print(word + '+' + wordPOS.upper())
    elif word in derivedWords:
        wordSuffixes = derivedWords[word]
        print(wordSuffixes[0][0] + '+' + wordSuffixes[0][1].upper(), end='')
        for suffix in wordSuffixes[1:]:
            print('+' + suffix[0] + '(' + suffix[1] + '->' + suffix[2] + ')', end='')
    else:
        print("No such word in lexicon!")
        
def lexSurface(lex):
    wordFound = True
    stem = lex.split('+')[0]
    wordSuffixes = lex.split('+')[2:]
    if len(wordSuffixes) == 0 and stem in stems:
        print(stem)
    else:
        for w, wsuffixes in derivedWords.items():
            wordFound = False
            if stem == wsuffixes[0][0] and len(wordSuffixes)+1 == len(wsuffixes):
                wordFound = True
                for i, ws in enumerate(wsuffixes[1:]):
                    if wordSuffixes[i] != ws[0]:
                        wordFound = False
                        break
                if wordFound:
                    print(w)
                    break
    if not wordFound:
        print("No such word in lexicon!")

# %%
surfaceLex('methodological')
# Out:
# method+N+logy(n->n)+ical(n->adj)

# %%
lexSurface('method+N+logy+ical')
# Out:
# methodological
